# %% [markdown]
# ### Export each patient case (user query) + the LLMs and RAG-enhanced LLMs diagnoses in a PDF file

# %%
import os
import pandas as pd
from fpdf import FPDF

# Load CSV file
df = pd.read_csv("./rag_gemini.csv")
# Define output folder
output_folder = "./rag_gemini_pdfs"
os.makedirs(output_folder, exist_ok=True)

# Create PDF class
class PDF(FPDF):
    def header(self):
        self.set_font("Arial", "B", 12)

    def chapter_title(self, title):
        self.set_font("Arial", "B", 14)
        self.cell(0, 10, title.encode('latin-1', 'replace').decode('latin-1'), ln=True, align="L")
        self.ln(5)

    def chapter_content(self, content):
        self.set_font("Arial", "", 10)
        self.multi_cell(0, 10, content.encode('latin-1', 'replace').decode('latin-1'))
        self.ln(5)

# Define the row range to process (inclusive)
start_row = 100  # Adjust as needed
end_row = 149 # Adjust as needed (inclusive)

# Add content from a specific range of rows in the CSV
for index, row in df.iloc[start_row:end_row + 1].iterrows():
    pdf = PDF()
    pdf.set_auto_page_break(auto=True, margin=15)
    pdf.add_page()
    pdf.chapter_title("User Query")
    pdf.chapter_content(str(row["p_prompt"]).replace("Õ", "'"))
    pdf.chapter_title("LLM Response 1")
    pdf.chapter_content(str(row["llm_response"]))
    pdf.chapter_title("LLM Response 2")
    pdf.chapter_content(str(row["llm_rag_response"]))

# For pdfs 1-50, LLM Response 1 = Base LLM
# For pdfs 51-100, LLM Response 1 = RAG LLM
# For pdfs 101-150, LLM Response 1 = Base LLM
# For pdfs 151-214, LLM Response 1 = RAG LLM

    # Save each PDF file separately
    output_filename = os.path.join(output_folder, f"rag_gemini_row_{index + 1}.pdf")
    pdf.output(output_filename)
    print(f"PDF generated successfully and saved as '{output_filename}'")

# %% [markdown]
# ### Update the names of the files to avoid bias during evaluation

# %%
import os

def rename_files_in_folder(folder_path, old_str, new_str):
    # Check if the folder path exists
    if not os.path.exists(folder_path):
        print(f"The folder '{folder_path}' does not exist.")
        return

    # Iterate over all files in the folder
    for filename in os.listdir(folder_path):
        # Construct the full file path
        file_path = os.path.join(folder_path, filename)

        # Check if it's a file (not a directory)
        if os.path.isfile(file_path):
            # Replace 'abc' with 'def' in the filename
            new_filename = filename.replace(old_str, new_str)

            # If the filename has changed, rename the file
            if new_filename != filename:
                new_file_path = os.path.join(folder_path, new_filename)
                os.rename(file_path, new_file_path)
                print(f"Renamed: {filename} -> {new_filename}")

# Example usage
folder_path = "./rag_gemini_pdfs"  # Replace with your folder path
old_str = "gemini"
new_str = "llmA"

rename_files_in_folder(folder_path, old_str, new_str)
# Out:
# Renamed: rag_gpt3-5_row_1.pdf -> rag_llmB_row_1.pdf
# Renamed: rag_gpt3-5_row_10.pdf -> rag_llmB_row_10.pdf
# Renamed: rag_gpt3-5_row_100.pdf -> rag_llmB_row_100.pdf
# Renamed: rag_gpt3-5_row_101.pdf -> rag_llmB_row_101.pdf
# Renamed: rag_gpt3-5_row_102.pdf -> rag_llmB_row_102.pdf
# Renamed: rag_gpt3-5_row_103.pdf -> rag_llmB_row_103.pdf
# Renamed: rag_gpt3-5_row_104.pdf -> rag_llmB_row_104.pdf
# Renamed: rag_gpt3-5_row_105.pdf -> rag_llmB_row_105.pdf
# Renamed: rag_gpt3-5_row_106.pdf -> rag_llmB_row_106.pdf
# Renamed: rag_gpt3-5_row_107.pdf -> rag_llmB_row_107.pdf
# Renamed: rag_gpt3-5_row_108.pdf -> rag_llmB_row_108.pdf
# Renamed: rag_gpt3-5_row_109.pdf -> rag_llmB_row_109.pdf
# Renamed: rag_gpt3-5_row_11.pdf -> rag_llmB_row_11.pdf
# Renamed: rag_gpt3-5_row_110.pdf -> rag_llmB_row_110.pdf
# Renamed: rag_gpt3-5_row_111.pdf -> rag_llmB_row_111.pdf
# Renamed: rag_gpt3-5_row_112.pdf -> rag_llmB_row_112.pdf
# Renamed: rag_gpt3-5_row_113.pdf -> rag_llmB_row_113.pdf
# Renamed: rag_gpt3-5_row_114.pdf -> rag_llmB_row_114.pdf
# Renamed: rag_gpt3-5_row_115.pdf -> rag_llmB_row_115.pdf
# Renamed: rag_gpt3-5_row_116.pdf -> rag_llmB_row_116.pdf
# Renamed: rag_gpt3-5_row_117.pdf -> rag_llmB_row_117.pdf
# Renamed: rag_gpt3-5_row_118.pdf -> rag_llmB_row_118.pdf
# Renamed: rag_gpt3-5_row_119.pdf -> rag_llmB_row_119.pdf
# Renamed: rag_gpt3-5_row_12.pdf -> rag_llmB_row_12.pdf
# Renamed: rag_gpt3-5_row_120.pdf -> rag_llmB_row_120.pdf
# Renamed: rag_gpt3-5_row_121.pdf -> rag_llmB_row_121.pdf
# Renamed: rag_gpt3-5_row_122.pdf -> rag_llmB_row_122.pdf
# Renamed: rag_gpt3-5_row_123.pdf -> rag_llmB_row_123.pdf
# Renamed: rag_gpt3-5_row_124.pdf -> rag_llmB_row_124.pdf
# Renamed: rag_gpt3-5_row_125.pdf -> rag_llmB_row_125.pdf
# Renamed: rag_gpt3-5_row_126.pdf -> rag_llmB_row_126.pdf
# Renamed: rag_gpt3-5_row_127.pdf -> rag_llmB_row_127.pdf
# Renamed: rag_gpt3-5_row_128.pdf -> rag_llmB_row_128.pdf
# Renamed: rag_gpt3-5_row_129.pdf -> rag_llmB_row_129.pdf
# Renamed: rag_gpt3-5_row_13.pdf -> rag_llmB_row_13.pdf
# Renamed: rag_gpt3-5_row_130.pdf -> rag_llmB_row_130.pdf
# Renamed: rag_gpt3-5_row_131.pdf -> rag_llmB_row_131.pdf
# Renamed: rag_gpt3-5_row_132.pdf -> rag_llmB_row_132.pdf
# Renamed: rag_gpt3-5_row_133.pdf -> rag_llmB_row_133.pdf
# Renamed: rag_gpt3-5_row_134.pdf -> rag_llmB_row_134.pdf
# Renamed: rag_gpt3-5_row_135.pdf -> rag_llmB_row_135.pdf
# Renamed: rag_gpt3-5_row_136.pdf -> rag_llmB_row_136.pdf
# Renamed: rag_gpt3-5_row_137.pdf -> rag_llmB_row_137.pdf
# Renamed: rag_gpt3-5_row_138.pdf -> rag_llmB_row_138.pdf
# Renamed: rag_gpt3-5_row_139.pdf -> rag_llmB_row_139.pdf
# Renamed: rag_gpt3-5_row_14.pdf -> rag_llmB_row_14.pdf
# Renamed: rag_gpt3-5_row_140.pdf -> rag_llmB_row_140.pdf
# Renamed: rag_gpt3-5_row_141.pdf -> rag_llmB_row_141.pdf
# Renamed: rag_gpt3-5_row_142.pdf -> rag_llmB_row_142.pdf
# Renamed: rag_gpt3-5_row_143.pdf -> rag_llmB_row_143.pdf
# Renamed: rag_gpt3-5_row_144.pdf -> rag_llmB_row_144.pdf
# Renamed: rag_gpt3-5_row_145.pdf -> rag_llmB_row_145.pdf
# Renamed: rag_gpt3-5_row_146.pdf -> rag_llmB_row_146.pdf
# Renamed: rag_gpt3-5_row_147.pdf -> rag_llmB_row_147.pdf
# Renamed: rag_gpt3-5_row_148.pdf -> rag_llmB_row_148.pdf
# Renamed: rag_gpt3-5_row_149.pdf -> rag_llmB_row_149.pdf
# Renamed: rag_gpt3-5_row_15.pdf -> rag_llmB_row_15.pdf
# Renamed: rag_gpt3-5_row_150.pdf -> rag_llmB_row_150.pdf
# Renamed: rag_gpt3-5_row_151.pdf -> rag_llmB_row_151.pdf
# Renamed: rag_gpt3-5_row_152.pdf -> rag_llmB_row_152.pdf
# Renamed: rag_gpt3-5_row_153.pdf -> rag_llmB_row_153.pdf
# Renamed: rag_gpt3-5_row_154.pdf -> rag_llmB_row_154.pdf
# Renamed: rag_gpt3-5_row_155.pdf -> rag_llmB_row_155.pdf
# Renamed: rag_gpt3-5_row_156.pdf -> rag_llmB_row_156.pdf
# Renamed: rag_gpt3-5_row_157.pdf -> rag_llmB_row_157.pdf
# Renamed: rag_gpt3-5_row_158.pdf -> rag_llmB_row_158.pdf
# Renamed: rag_gpt3-5_row_159.pdf -> rag_llmB_row_159.pdf
# Renamed: rag_gpt3-5_row_16.pdf -> rag_llmB_row_16.pdf
# Renamed: rag_gpt3-5_row_160.pdf -> rag_llmB_row_160.pdf
# Renamed: rag_gpt3-5_row_161.pdf -> rag_llmB_row_161.pdf
# Renamed: rag_gpt3-5_row_162.pdf -> rag_llmB_row_162.pdf
# Renamed: rag_gpt3-5_row_163.pdf -> rag_llmB_row_163.pdf
# Renamed: rag_gpt3-5_row_164.pdf -> rag_llmB_row_164.pdf
# Renamed: rag_gpt3-5_row_165.pdf -> rag_llmB_row_165.pdf
# Renamed: rag_gpt3-5_row_166.pdf -> rag_llmB_row_166.pdf
# Renamed: rag_gpt3-5_row_167.pdf -> rag_llmB_row_167.pdf
# Renamed: rag_gpt3-5_row_168.pdf -> rag_llmB_row_168.pdf
# Renamed: rag_gpt3-5_row_169.pdf -> rag_llmB_row_169.pdf
# Renamed: rag_gpt3-5_row_17.pdf -> rag_llmB_row_17.pdf
# Renamed: rag_gpt3-5_row_170.pdf -> rag_llmB_row_170.pdf
# Renamed: rag_gpt3-5_row_171.pdf -> rag_llmB_row_171.pdf
# Renamed: rag_gpt3-5_row_172.pdf -> rag_llmB_row_172.pdf
# Renamed: rag_gpt3-5_row_173.pdf -> rag_llmB_row_173.pdf
# Renamed: rag_gpt3-5_row_174.pdf -> rag_llmB_row_174.pdf
# Renamed: rag_gpt3-5_row_175.pdf -> rag_llmB_row_175.pdf
# Renamed: rag_gpt3-5_row_176.pdf -> rag_llmB_row_176.pdf
# Renamed: rag_gpt3-5_row_177.pdf -> rag_llmB_row_177.pdf
# Renamed: rag_gpt3-5_row_178.pdf -> rag_llmB_row_178.pdf
# Renamed: rag_gpt3-5_row_179.pdf -> rag_llmB_row_179.pdf
# Renamed: rag_gpt3-5_row_18.pdf -> rag_llmB_row_18.pdf
# Renamed: rag_gpt3-5_row_180.pdf -> rag_llmB_row_180.pdf
# Renamed: rag_gpt3-5_row_181.pdf -> rag_llmB_row_181.pdf
# Renamed: rag_gpt3-5_row_182.pdf -> rag_llmB_row_182.pdf
# Renamed: rag_gpt3-5_row_183.pdf -> rag_llmB_row_183.pdf
# Renamed: rag_gpt3-5_row_184.pdf -> rag_llmB_row_184.pdf
# Renamed: rag_gpt3-5_row_185.pdf -> rag_llmB_row_185.pdf
# Renamed: rag_gpt3-5_row_186.pdf -> rag_llmB_row_186.pdf
# Renamed: rag_gpt3-5_row_187.pdf -> rag_llmB_row_187.pdf
# Renamed: rag_gpt3-5_row_188.pdf -> rag_llmB_row_188.pdf
# Renamed: rag_gpt3-5_row_189.pdf -> rag_llmB_row_189.pdf
# Renamed: rag_gpt3-5_row_19.pdf -> rag_llmB_row_19.pdf
# Renamed: rag_gpt3-5_row_190.pdf -> rag_llmB_row_190.pdf
# Renamed: rag_gpt3-5_row_191.pdf -> rag_llmB_row_191.pdf
# Renamed: rag_gpt3-5_row_192.pdf -> rag_llmB_row_192.pdf
# Renamed: rag_gpt3-5_row_193.pdf -> rag_llmB_row_193.pdf
# Renamed: rag_gpt3-5_row_194.pdf -> rag_llmB_row_194.pdf
# Renamed: rag_gpt3-5_row_195.pdf -> rag_llmB_row_195.pdf
# Renamed: rag_gpt3-5_row_196.pdf -> rag_llmB_row_196.pdf
# Renamed: rag_gpt3-5_row_197.pdf -> rag_llmB_row_197.pdf
# Renamed: rag_gpt3-5_row_198.pdf -> rag_llmB_row_198.pdf
# Renamed: rag_gpt3-5_row_199.pdf -> rag_llmB_row_199.pdf
# Renamed: rag_gpt3-5_row_2.pdf -> rag_llmB_row_2.pdf
# Renamed: rag_gpt3-5_row_20.pdf -> rag_llmB_row_20.pdf
# Renamed: rag_gpt3-5_row_200.pdf -> rag_llmB_row_200.pdf
# Renamed: rag_gpt3-5_row_201.pdf -> rag_llmB_row_201.pdf
# Renamed: rag_gpt3-5_row_202.pdf -> rag_llmB_row_202.pdf
# Renamed: rag_gpt3-5_row_203.pdf -> rag_llmB_row_203.pdf
# Renamed: rag_gpt3-5_row_204.pdf -> rag_llmB_row_204.pdf
# Renamed: rag_gpt3-5_row_205.pdf -> rag_llmB_row_205.pdf
# Renamed: rag_gpt3-5_row_206.pdf -> rag_llmB_row_206.pdf
# Renamed: rag_gpt3-5_row_207.pdf -> rag_llmB_row_207.pdf
# Renamed: rag_gpt3-5_row_208.pdf -> rag_llmB_row_208.pdf
# Renamed: rag_gpt3-5_row_209.pdf -> rag_llmB_row_209.pdf
# Renamed: rag_gpt3-5_row_21.pdf -> rag_llmB_row_21.pdf
# Renamed: rag_gpt3-5_row_210.pdf -> rag_llmB_row_210.pdf
# Renamed: rag_gpt3-5_row_211.pdf -> rag_llmB_row_211.pdf
# Renamed: rag_gpt3-5_row_212.pdf -> rag_llmB_row_212.pdf
# Renamed: rag_gpt3-5_row_213.pdf -> rag_llmB_row_213.pdf
# Renamed: rag_gpt3-5_row_214.pdf -> rag_llmB_row_214.pdf
# Renamed: rag_gpt3-5_row_22.pdf -> rag_llmB_row_22.pdf
# Renamed: rag_gpt3-5_row_23.pdf -> rag_llmB_row_23.pdf
# Renamed: rag_gpt3-5_row_24.pdf -> rag_llmB_row_24.pdf
# Renamed: rag_gpt3-5_row_25.pdf -> rag_llmB_row_25.pdf
# Renamed: rag_gpt3-5_row_26.pdf -> rag_llmB_row_26.pdf
# Renamed: rag_gpt3-5_row_27.pdf -> rag_llmB_row_27.pdf
# Renamed: rag_gpt3-5_row_28.pdf -> rag_llmB_row_28.pdf
# Renamed: rag_gpt3-5_row_29.pdf -> rag_llmB_row_29.pdf
# Renamed: rag_gpt3-5_row_3.pdf -> rag_llmB_row_3.pdf
# Renamed: rag_gpt3-5_row_30.pdf -> rag_llmB_row_30.pdf
# Renamed: rag_gpt3-5_row_31.pdf -> rag_llmB_row_31.pdf
# Renamed: rag_gpt3-5_row_32.pdf -> rag_llmB_row_32.pdf
# Renamed: rag_gpt3-5_row_33.pdf -> rag_llmB_row_33.pdf
# Renamed: rag_gpt3-5_row_34.pdf -> rag_llmB_row_34.pdf
# Renamed: rag_gpt3-5_row_35.pdf -> rag_llmB_row_35.pdf
# Renamed: rag_gpt3-5_row_36.pdf -> rag_llmB_row_36.pdf
# Renamed: rag_gpt3-5_row_37.pdf -> rag_llmB_row_37.pdf
# Renamed: rag_gpt3-5_row_38.pdf -> rag_llmB_row_38.pdf
# Renamed: rag_gpt3-5_row_39.pdf -> rag_llmB_row_39.pdf
# Renamed: rag_gpt3-5_row_4.pdf -> rag_llmB_row_4.pdf
# Renamed: rag_gpt3-5_row_40.pdf -> rag_llmB_row_40.pdf
# Renamed: rag_gpt3-5_row_41.pdf -> rag_llmB_row_41.pdf
# Renamed: rag_gpt3-5_row_42.pdf -> rag_llmB_row_42.pdf
# Renamed: rag_gpt3-5_row_43.pdf -> rag_llmB_row_43.pdf
# Renamed: rag_gpt3-5_row_44.pdf -> rag_llmB_row_44.pdf
# Renamed: rag_gpt3-5_row_45.pdf -> rag_llmB_row_45.pdf
# Renamed: rag_gpt3-5_row_46.pdf -> rag_llmB_row_46.pdf
# Renamed: rag_gpt3-5_row_47.pdf -> rag_llmB_row_47.pdf
# Renamed: rag_gpt3-5_row_48.pdf -> rag_llmB_row_48.pdf
# Renamed: rag_gpt3-5_row_49.pdf -> rag_llmB_row_49.pdf
# Renamed: rag_gpt3-5_row_5.pdf -> rag_llmB_row_5.pdf
# Renamed: rag_gpt3-5_row_50.pdf -> rag_llmB_row_50.pdf
# Renamed: rag_gpt3-5_row_51.pdf -> rag_llmB_row_51.pdf
# Renamed: rag_gpt3-5_row_52.pdf -> rag_llmB_row_52.pdf
# Renamed: rag_gpt3-5_row_53.pdf -> rag_llmB_row_53.pdf
# Renamed: rag_gpt3-5_row_54.pdf -> rag_llmB_row_54.pdf
# Renamed: rag_gpt3-5_row_55.pdf -> rag_llmB_row_55.pdf
# Renamed: rag_gpt3-5_row_56.pdf -> rag_llmB_row_56.pdf
# Renamed: rag_gpt3-5_row_57.pdf -> rag_llmB_row_57.pdf
# Renamed: rag_gpt3-5_row_58.pdf -> rag_llmB_row_58.pdf
# Renamed: rag_gpt3-5_row_59.pdf -> rag_llmB_row_59.pdf
# Renamed: rag_gpt3-5_row_6.pdf -> rag_llmB_row_6.pdf
# Renamed: rag_gpt3-5_row_60.pdf -> rag_llmB_row_60.pdf
# Renamed: rag_gpt3-5_row_61.pdf -> rag_llmB_row_61.pdf
# Renamed: rag_gpt3-5_row_62.pdf -> rag_llmB_row_62.pdf
# Renamed: rag_gpt3-5_row_63.pdf -> rag_llmB_row_63.pdf
# Renamed: rag_gpt3-5_row_64.pdf -> rag_llmB_row_64.pdf
# Renamed: rag_gpt3-5_row_65.pdf -> rag_llmB_row_65.pdf
# Renamed: rag_gpt3-5_row_66.pdf -> rag_llmB_row_66.pdf
# Renamed: rag_gpt3-5_row_67.pdf -> rag_llmB_row_67.pdf
# Renamed: rag_gpt3-5_row_68.pdf -> rag_llmB_row_68.pdf
# Renamed: rag_gpt3-5_row_69.pdf -> rag_llmB_row_69.pdf
# Renamed: rag_gpt3-5_row_7.pdf -> rag_llmB_row_7.pdf
# Renamed: rag_gpt3-5_row_70.pdf -> rag_llmB_row_70.pdf
# Renamed: rag_gpt3-5_row_71.pdf -> rag_llmB_row_71.pdf
# Renamed: rag_gpt3-5_row_72.pdf -> rag_llmB_row_72.pdf
# Renamed: rag_gpt3-5_row_73.pdf -> rag_llmB_row_73.pdf
# Renamed: rag_gpt3-5_row_74.pdf -> rag_llmB_row_74.pdf
# Renamed: rag_gpt3-5_row_75.pdf -> rag_llmB_row_75.pdf
# Renamed: rag_gpt3-5_row_76.pdf -> rag_llmB_row_76.pdf
# Renamed: rag_gpt3-5_row_77.pdf -> rag_llmB_row_77.pdf
# Renamed: rag_gpt3-5_row_78.pdf -> rag_llmB_row_78.pdf
# Renamed: rag_gpt3-5_row_79.pdf -> rag_llmB_row_79.pdf
# Renamed: rag_gpt3-5_row_8.pdf -> rag_llmB_row_8.pdf
# Renamed: rag_gpt3-5_row_80.pdf -> rag_llmB_row_80.pdf
# Renamed: rag_gpt3-5_row_81.pdf -> rag_llmB_row_81.pdf
# Renamed: rag_gpt3-5_row_82.pdf -> rag_llmB_row_82.pdf
# Renamed: rag_gpt3-5_row_83.pdf -> rag_llmB_row_83.pdf
# Renamed: rag_gpt3-5_row_84.pdf -> rag_llmB_row_84.pdf
# Renamed: rag_gpt3-5_row_85.pdf -> rag_llmB_row_85.pdf
# Renamed: rag_gpt3-5_row_86.pdf -> rag_llmB_row_86.pdf
# Renamed: rag_gpt3-5_row_87.pdf -> rag_llmB_row_87.pdf
# Renamed: rag_gpt3-5_row_88.pdf -> rag_llmB_row_88.pdf
# Renamed: rag_gpt3-5_row_89.pdf -> rag_llmB_row_89.pdf
# Renamed: rag_gpt3-5_row_9.pdf -> rag_llmB_row_9.pdf
# Renamed: rag_gpt3-5_row_90.pdf -> rag_llmB_row_90.pdf
# Renamed: rag_gpt3-5_row_91.pdf -> rag_llmB_row_91.pdf
# Renamed: rag_gpt3-5_row_92.pdf -> rag_llmB_row_92.pdf
# Renamed: rag_gpt3-5_row_93.pdf -> rag_llmB_row_93.pdf
# Renamed: rag_gpt3-5_row_94.pdf -> rag_llmB_row_94.pdf
# Renamed: rag_gpt3-5_row_95.pdf -> rag_llmB_row_95.pdf
# Renamed: rag_gpt3-5_row_96.pdf -> rag_llmB_row_96.pdf
# Renamed: rag_gpt3-5_row_97.pdf -> rag_llmB_row_97.pdf
# Renamed: rag_gpt3-5_row_98.pdf -> rag_llmB_row_98.pdf
# Renamed: rag_gpt3-5_row_99.pdf -> rag_llmB_row_99.pdf
